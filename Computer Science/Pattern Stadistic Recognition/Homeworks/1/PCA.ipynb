# %% [markdown]
#  Referencia para leer archivos en colab usando Python: https://towardsdatascience.com/3-ways-to-load-csv-files-into-colab-7c14fcbdcb92

# %%
import io
import pandas as pd
d = pd.read_csv('heptatlon.txt', sep=" ")

d.head()
# Out:
#                      hurdles  highjump   shot  run200m  longjump  javelin  \
# Joyner-Kersee (USA)    12.69      1.86  15.80    22.56      7.27    45.66
# John (GDR)             12.85      1.80  16.23    23.65      6.71    42.56
# Behmer (GDR)           13.20      1.83  14.20    23.10      6.68    44.54
# Sablovskaite (URS)     13.61      1.80  15.23    23.92      6.25    42.78
# Choubenkova (URS)      13.51      1.74  14.76    23.93      6.32    47.46
#
#                      run800m  score
# Joyner-Kersee (USA)   128.51   7291
# John (GDR)            126.12   6897
# Behmer (GDR)          124.20   6858
# Sablovskaite (URS)    132.24   6540
# Choubenkova (URS)     127.90   6540

# %%
d.columns=['V1', 'V2', 'V3', 'V4', 'V5','V6', 'V7', 'V8']

# %%
d.head()
# Out:
#                         V1    V2     V3     V4    V5     V6      V7    V8
# Joyner-Kersee (USA)  12.69  1.86  15.80  22.56  7.27  45.66  128.51  7291
# John (GDR)           12.85  1.80  16.23  23.65  6.71  42.56  126.12  6897
# Behmer (GDR)         13.20  1.83  14.20  23.10  6.68  44.54  124.20  6858
# Sablovskaite (URS)   13.61  1.80  15.23  23.92  6.25  42.78  132.24  6540
# Choubenkova (URS)    13.51  1.74  14.76  23.93  6.32  47.46  127.90  6540

# %%
d[d.V2 > 23]
# Out:
# Empty DataFrame
# Columns: [V1, V2, V3, V4, V5, V6, V7, V8]
# Index: []

# %%
import seaborn as sns

# %%
sns.pairplot(d)

# %%
sns.pairplot(d,diag_kind = 'kde')

# %% [markdown]
# #Hacer PCA

# %%
from sklearn.decomposition import PCA
from pprint import pprint

# %%
pca=PCA(7) # se puede especificar náximo número de componentes o % varianza explicada que se quiere alcanzar

# %%
pca.fit(d)
# Out:
# PCA(n_components=7)

# %% [markdown]
# Investigar loadings

# %%
pprint(pca.components_)
# Out:
# array([[ 1.19624885e-03, -1.05204013e-04, -2.09849444e-03,
#          1.47499229e-03, -7.92784821e-04, -1.57865298e-03,
#          1.12710147e-02, -9.99930909e-01],
#        [ 1.92835321e-02, -6.05680149e-04,  8.27323011e-02,
#         -1.73321242e-02,  1.08856631e-03,  3.27484685e-01,
#          9.40817259e-01,  9.91075581e-03],
#        [-4.42281031e-02,  5.20709703e-03,  5.23034341e-02,
#          2.52425088e-02,  3.33247513e-02, -9.42375189e-01,
#          3.24711313e-01,  4.99545357e-03],
#        [ 1.27735048e-01, -3.39503633e-02,  9.78341573e-01,
#          1.16494549e-01, -5.42199304e-02,  1.74323988e-02,
#         -9.25021755e-02, -2.75215967e-03],
#        [ 2.99253782e-02, -6.54426901e-02,  1.10968349e-01,
#         -9.90594181e-01,  8.48590375e-03, -2.83264257e-02,
#         -1.87933943e-02, -1.82525884e-03],
#        [-9.77750566e-01,  1.11049607e-02,  1.19861716e-01,
#         -1.94015933e-02, -1.64765138e-01,  4.41739357e-02,
# ...

# %%
pprint(pca.explained_variance_ratio_)
# Out:
# array([9.99874407e-01, 9.31983717e-05, 2.97317839e-05, 1.83140815e-06,
#        6.73580569e-07, 1.29704823e-07, 2.61302975e-08])

# %%
pca=PCA(8) # se puede especificar náximo número de componentes o % varianza explicada que se quiere alcanzar

# %%
pca.fit(d)
# Out:
# PCA(n_components=8)

# %%
pprint(pca.components_)
# Out:
# array([[ 1.19624885e-03, -1.05204013e-04, -2.09849444e-03,
#          1.47499229e-03, -7.92784821e-04, -1.57865298e-03,
#          1.12710147e-02, -9.99930909e-01],
#        [ 1.92835321e-02, -6.05680149e-04,  8.27323011e-02,
#         -1.73321242e-02,  1.08856631e-03,  3.27484685e-01,
#          9.40817259e-01,  9.91075581e-03],
#        [-4.42281031e-02,  5.20709703e-03,  5.23034341e-02,
#          2.52425088e-02,  3.33247513e-02, -9.42375189e-01,
#          3.24711313e-01,  4.99545357e-03],
#        [ 1.27735048e-01, -3.39503633e-02,  9.78341573e-01,
#          1.16494549e-01, -5.42199304e-02,  1.74323988e-02,
#         -9.25021755e-02, -2.75215967e-03],
#        [ 2.99253782e-02, -6.54426901e-02,  1.10968349e-01,
#         -9.90594181e-01,  8.48590375e-03, -2.83264257e-02,
#         -1.87933943e-02, -1.82525884e-03],
#        [-9.77750566e-01,  1.11049607e-02,  1.19861716e-01,
#         -1.94015933e-02, -1.64765138e-01,  4.41739357e-02,
# ...

# %%
pprint(pca.explained_variance_ratio_)
# Out:
# array([9.99874407e-01, 9.31983717e-05, 2.97317839e-05, 1.83140815e-06,
#        6.73580569e-07, 1.29704823e-07, 2.61302975e-08, 1.74968462e-09])

# %%
pca.fit_transform(d)
# Out:
# array([[-1.20041967e+03,  6.40457056e+00, -2.13871977e-01,
#         -3.62247071e-01,  1.69576174e-01, -2.17054474e-01,
#         -1.13847301e-01, -3.37892019e-02],
#        [-8.06467586e+02, -7.44828019e-01, -1.28236046e-02,
#          1.48964733e+00, -6.61246317e-03,  2.00407551e-01,
#         -3.52216085e-02, -1.67804662e-02],
#        [-7.67491158e+02, -2.44101245e+00, -2.83337761e+00,
#         -1.95688160e-01,  3.72386702e-01, -2.13291555e-01,
#          3.31675377e-02, -1.85575973e-03],
#        [-4.49419849e+02,  1.47362319e+00, -1.10720536e-01,
#          1.08502190e+00,  1.64168549e-01, -9.86055254e-02,
#          2.19826583e-01,  4.50291368e-03],
#        [-4.49475321e+02, -1.11776871e+00, -5.94817059e+00,
#          1.09487750e+00,  5.26311794e-02,  1.63302649e-01,
#         -9.93172003e-02, -1.28572059e-02],
#        [-3.20496715e+02, -6.01304697e+00, -2.96264467e+00,
#          4.42423729e-01, -3.92492575e-01, -2.41180962e-01,
# ...

# %%
pprint(pca.components_)
# Out:
# array([[ 1.19624885e-03, -1.05204013e-04, -2.09849444e-03,
#          1.47499229e-03, -7.92784821e-04, -1.57865298e-03,
#          1.12710147e-02, -9.99930909e-01],
#        [ 1.92835321e-02, -6.05680149e-04,  8.27323011e-02,
#         -1.73321242e-02,  1.08856631e-03,  3.27484685e-01,
#          9.40817259e-01,  9.91075581e-03],
#        [-4.42281031e-02,  5.20709703e-03,  5.23034341e-02,
#          2.52425088e-02,  3.33247513e-02, -9.42375189e-01,
#          3.24711313e-01,  4.99545357e-03],
#        [ 1.27735048e-01, -3.39503633e-02,  9.78341573e-01,
#          1.16494549e-01, -5.42199304e-02,  1.74323988e-02,
#         -9.25021755e-02, -2.75215967e-03],
#        [ 2.99253782e-02, -6.54426901e-02,  1.10968349e-01,
#         -9.90594181e-01,  8.48590375e-03, -2.83264257e-02,
#         -1.87933943e-02, -1.82525884e-03],
#        [-9.77750566e-01,  1.11049607e-02,  1.19861716e-01,
#         -1.94015933e-02, -1.64765138e-01,  4.41739357e-02,
# ...

# %%
pprint(pca.explained_variance_ratio_)
# Out:
# array([9.99874407e-01, 9.31983717e-05, 2.97317839e-05, 1.83140815e-06,
#        6.73580569e-07, 1.29704823e-07, 2.61302975e-08, 1.74968462e-09])

# %% [markdown]
# Repetir lo anterior pero con datos estandarizados

# %%
from sklearn.preprocessing import StandardScaler

# %%
d_std = StandardScaler().fit_transform(d)

# %%
pca.fit(d_std)
# Out:
# PCA(n_components=8)

# %%
pca.components_
# Out:
# array([[ 0.4073494 , -0.33892709, -0.33224949,  0.37039666, -0.41221153,
#         -0.07767939,  0.33775722, -0.426121  ],
#        [ 0.17794781, -0.26354914,  0.27292253, -0.24019801, -0.07586727,
#          0.83595531,  0.2394984 ,  0.0689784 ],
#        [-0.04379636,  0.36707058, -0.67727657,  0.08550058, -0.14063523,
#          0.47065239, -0.3949711 ,  0.00575067],
#        [-0.02504152,  0.67886203,  0.12345228,  0.36301403,  0.1098862 ,
#          0.11971721,  0.60419719,  0.00617874],
#        [-0.11296371, -0.0055608 , -0.49392063, -0.66465635,  0.19783514,
#         -0.12395442,  0.49117898, -0.07564655],
#        [-0.79481441, -0.08026477,  0.07712471,  0.00983509, -0.57216639,
#          0.03948078,  0.13279381, -0.09599674],
#        [-0.38211458, -0.43876198, -0.22343169,  0.45687497,  0.60197516,
#          0.1697473 ,  0.1049272 ,  0.0249393 ],
#        [-0.09671374,  0.14522528,  0.20335199, -0.12418603,  0.25216138,
# ...

# %%
pca.explained_variance_ratio_
# Out:
# array([6.80783424e-01, 1.50215552e-01, 6.51294454e-02, 5.71485485e-02,
#        3.08735060e-02, 9.21936473e-03, 6.12962079e-03, 5.00537787e-04])

# %% [markdown]
# Pedir scores (proyecciones):

# %%
scores = pd.DataFrame(pca.fit_transform(d_std))

# %%
scores.shape
# Out:
# (25, 8)

# %%
scores.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -4.736449  1.225393 -0.379306  0.021967  0.437298 -0.354682  0.354295
# 1 -3.284407  0.502814 -0.916888 -0.485506 -0.710132  0.249374  0.147288
# 2 -3.040701  0.665530  0.467417 -0.694681  0.109439 -0.245601 -0.133261
# 3 -1.592147  0.699476 -0.607572 -0.143143 -0.465281  0.093022 -0.494525
# 4 -1.618764  1.778373  0.152626 -0.853871 -0.693036  0.137551  0.243100
#
#           7
# 0 -0.049918
# 1  0.013010
# 2 -0.028873
# 3 -0.079023
# 4  0.052052

# %% [markdown]
# Un biplot sencillo pero sin reescalar las variables:

# %%
sns.relplot(x=scores.iloc[:,0],y=scores.iloc[:,1])

# %% [markdown]
# Abajo algo más completo, basado en: https://stackify.dev/528450-plot-pca-loadings-and-loading-in-biplot-in-sklearn-like-rs-autoplot

# %%
import numpy as np
import matplotlib.pyplot as plt

def myplot(score,coeff,labels=None):
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())
    plt.scatter(xs * scalex,ys * scaley)
    for i in range(n):
        plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
        if labels is None:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'g', ha = 'center', va = 'center')
        else:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'g', ha = 'center', va = 'center')
    plt.xlim(-1,1)
    plt.ylim(-1,1)
    plt.xlabel("PC{}".format(1))
    plt.ylabel("PC{}".format(2))
    plt.grid()

# %%
scores=pca.fit_transform(d_std)
myplot(scores[:,0:2],np.transpose(pca.components_[0:2, :]))
